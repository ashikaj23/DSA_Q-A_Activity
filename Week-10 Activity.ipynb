# %% [markdown]
# # Week 7 Activity

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn import preprocessing

# %% [markdown]
# ## 1. Read the data into python

# %%
data=pd.read_csv('week10.csv')

# %%
data
# Out:
#              ph    Hardness       Solids  Chloramines     Sulfate  \
# 0      8.316766  214.373394  22018.41744     8.059332  356.886136
# 1      9.092223  181.101509  17978.98634     6.546600  310.135738
# 2      5.584087  188.313324  28748.68774     7.544869  326.678363
# 3     10.223862  248.071735  28749.71654     7.513408  393.663395
# 4      8.635849  203.361523  13672.09176     4.563009  303.309771
# ...         ...         ...          ...          ...         ...
# 2006   8.989900  215.047358  15921.41202     6.297312  312.931021
# 2007   6.702547  207.321086  17246.92035     7.708117  304.510230
# 2008  11.491011   94.812545  37188.82602     9.263166  258.930600
# 2009   6.069616  186.659040  26138.78019     7.747547  345.700257
# 2010   4.668102  193.681736  47580.99160     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       363.266516       18.436525       100.341674   4.628771
# ...

# %% [markdown]
# ## 2. Check for null values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2011 non-null   float64
#  1   Hardness         2011 non-null   float64
#  2   Solids           2011 non-null   float64
#  3   Chloramines      2011 non-null   float64
#  4   Sulfate          2011 non-null   float64
#  5   Conductivity     2011 non-null   float64
#  6   Organic_carbon   2011 non-null   float64
#  7   Trihalomethanes  2011 non-null   float64
#  8   Turbidity        2011 non-null   float64
# dtypes: float64(9)
# memory usage: 141.5 KB

# %%
data.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# dtype: int64

# %% [markdown]
# There is no null value in any of the columns

# %% [markdown]
# ## 3. Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and comment on your observations.

# %%
data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2011.000000  2011.000000   2011.000000  2011.000000  2011.000000
# mean      7.085990   195.968072  21917.441375     7.134338   333.224672
# std       1.573337    32.635085   8642.239815     1.584820    41.205172
# min       0.227499    73.492234    320.942611     1.390871   129.000000
# 25%       6.089723   176.744938  15615.665390     6.138895   307.632511
# 50%       7.027297   197.191839  20933.512750     7.143907   332.232177
# 75%       8.052969   216.441070  27182.587065     8.109726   359.330555
# max      14.000000   317.338124  56488.672410    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity
# count   2011.000000     2011.000000      2011.000000  2011.000000
# mean     426.526409       14.357709        66.400859     3.969729
# std       80.712572        3.324959        16.077109     0.780346
# ...

# %%
data.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity'],
#       dtype='object')

# %%
plt.figure(figsize=(10,15))

plt.subplot(3,1,1)
plt.scatter(data['Hardness'],data['Sulfate'],s=12, c='red',marker='^')
plt.title('Plot of Hardness VS Sulfate',fontsize=16)
plt.xlabel('Hardness')
plt.ylabel('Sulfate')

plt.subplot(3,1,2)
plt.scatter(data['Organic_carbon'],data['Hardness'],s=12, c='red',marker='^')
plt.title('Plot of Organic_carbon VS Hardness',fontsize=16)
plt.xlabel('Organic_carbon')
plt.ylabel('Hardness')

plt.subplot(3,1,3)
plt.scatter(data['Sulfate'],data['Organic_carbon'],s=12, c='red',marker='^')
plt.title('Plot of Sulfate VS Organic_carbon',fontsize=16)
plt.xlabel('Sulfate')
plt.ylabel('Organic_carbon')

plt.tight_layout()

# %%
plt.boxplot(data['Sulfate'])
plt.title('Box plot of Sulfate')
plt.xlabel('Sulfate')
# Out:
# Text(0.5, 0, 'Sulfate')

# %%
plt.boxplot(data['Hardness'])
plt.title('Box plot of Hardness')
plt.xlabel('Hardness')
# Out:
# Text(0.5, 0, 'Hardness')

# %%
plt.boxplot(data['Organic_carbon'])
plt.title('Box plot of Organic_carbon')
plt.xlabel('Organic_carbon')
# Out:
# Text(0.5, 0, 'Organic_carbon')

# %%
fig,ax =plt.subplots(figsize=(10,8))
sns.distplot(data.Sulfate)
plt.show()

# %%
fig,ax =plt.subplots(figsize=(10,8))
sns.distplot(data.Hardness)
plt.show()

# %%
fig,ax =plt.subplots(figsize=(10,8))
sns.distplot(data.Organic_carbon)
plt.show()

# %% [markdown]
# ## 4. Carry out correlation analysis on the dataset and find the correlation factor between
# ## a. ph and Chloramines
# ## b. ph and Conductivity
# ## What do we infer from this correlation value?

# %%
corrmatrix=data.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corrmatrix,vmin=-2,vmax=.9,annot=True,linewidth=0.2,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
data[['ph','Chloramines']].corr()
# Out:
#                    ph  Chloramines
# ph           1.000000    -0.024768
# Chloramines -0.024768     1.000000

# %%
data[['ph','Conductivity']].corr()
# Out:
#                     ph  Conductivity
# ph            1.000000      0.014128
# Conductivity  0.014128      1.000000
