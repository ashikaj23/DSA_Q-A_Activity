# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('Dataset_w6.xlsx - Data.csv')
data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0                652864                           35530
# 1                 28748                            2930
# 2               2381741                           41318
# ...

# %% [markdown]
# ## 1. Find out how many countries are there in the dataset.

# %%
dt1=data['country']
dt1
# Out:
# 0                             Afghanistan
# 1                                 Albania
# 2                                 Algeria
# 3                                  Angola
# 4                     Antigua and Barbuda
#                       ...
# 191    Venezuela (Bolivarian Republic of)
# 192                              Viet Nam
# 193                                 Yemen
# 194                                Zambia
# 195                              Zimbabwe
# Name: country, Length: 196, dtype: object

# %%
print('No. of countries listed in the dataset :',dt1.count())
# Out:
# No. of countries listed in the dataset : 196

# %% [markdown]
# ## 2. Examine the data by using visualizations.

# %%
plt.figure(figsize=(10,20))

plt.subplot(4,1,1)
plt.scatter(data['International trade: Imports (million US$)'],data['Agricultural production index '],s=30,alpha=0.5, c='red')
plt.title('Plot of Agricultural production index VS International trade: Imports',fontsize=16)
plt.xlabel('International trade: Imports (million US$)')
plt.ylabel('Agricultural production index')

plt.subplot(4,1,2)
plt.scatter(data['GDP per capita (current US$)'],data['Population in thousands (2017)'],s=30, c='Blue',alpha=0.5)
plt.title('Plot of Population VS GDP per capita ',fontsize=16)
plt.xlabel('GDP per capita (current US$)')
plt.ylabel('Population in thousands (2017)')

plt.subplot(4,1,3)
plt.scatter(data['Surface area (km2)'],data['Population in thousands (2017)'],s=30, c='Green', alpha=0.5)
plt.title('Plot of Surface area VS Population',fontsize=16)
plt.xlabel('Surface area (km2)')
plt.ylabel('Population in thousands (2017)')

plt.subplot(4,1,4)
plt.scatter(data['GDP per capita (current US$)'],data['Agricultural production index '],s=30, c='violet',alpha=0.5)
plt.title('Plot of GDP per capita (current US$) VS Agricultural production index ',fontsize=16)
plt.xlabel('GDP per capita (current US$)')
plt.ylabel('Agricultural production index ')

plt.tight_layout()

# %%
dt=data.sort_values(by='Agricultural production index ',ascending=False)

bdt=dt[['country','Region','Agricultural production index ']]
bdt1=data['Agricultural production index '].mean()
bdt2= bdt[bdt['Agricultural production index ']>=bdt1]
bdt2
# Out:
#                                 country             Region  \
# 95                               Kuwait        WesternAsia
# 97     Lao People's Democratic Republic  South-easternAsia
# 194                              Zambia      EasternAfrica
# 186         United Republic of Tanzania      EasternAfrica
# 3                                Angola       MiddleAfrica
# ..                                  ...                ...
# 151               Sao Tome and Principe       MiddleAfrica
# 105                          Madagascar      EasternAfrica
# 160                     Solomon Islands          Melanesia
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 55                              Ecuador       SouthAmerica
#
#      Agricultural production index
# 95                              199
# 97                              193
# 194                             179
# 186                             176
# 3                               175
# ...

# %%
plt.figure(figsize=(14,7))
sns.countplot(x='Region',data=bdt2)
plt.title('Count of COuntries in a Region above the average Agricultural Production Index')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 3. Find out how many countries with respect to the region are available in the dataset

# %%
dt2=data['Region'].value_counts()
dt2
# Out:
# WesternAsia          18
# EasternAfrica        17
# Caribbean            16
# WesternAfrica        15
# SouthAmerica         12
# SouthernEurope       12
# South-easternAsia    11
# EasternEurope        10
# NorthernEurope       10
# SouthernAsia          9
# MiddleAfrica          9
# CentralAmerica        8
# WesternEurope         7
# EasternAsia           7
# SouthernAfrica        5
# Polynesia             5
# NorthernAfrica        5
# Melanesia             5
# CentralAsia           5
# NorthernAmerica       4
# Micronesia            4
# Oceania               2
# Name: Region, dtype: int64

# %% [markdown]
# ## 4. On average which region has the highest
# ## a. GDP per capita (current US)
# ## b. International trade: Imports (million US)

# %%
data.groupby('Region')['Region','GDP per capita (current US$)','International trade: Imports (million US$)'].mean()
# Out:
#                    GDP per capita (current US$)  \
# Region
# Caribbean                          15135.562500
# CentralAmerica                      6348.137500
# CentralAsia                         4329.880000
# EasternAfrica                       2088.852941
# EasternAsia                        27967.614286
# EasternEurope                       9292.490000
# Melanesia                           9261.960000
# Micronesia                          5008.300000
# MiddleAfrica                        3928.833333
# NorthernAfrica                      3934.960000
# NorthernAmerica                    57659.000000
# NorthernEurope                     42098.220000
# Oceania                            44823.250000
# Polynesia                           8686.520000
# South-easternAsia                  10299.027273
# SouthAmerica                        8499.775000
# SouthernAfrica                      4191.900000
# SouthernAsia                        2968.400000
# ...

# %%
hgdp=data.groupby('Region')['GDP per capita (current US$)'].mean()
hgdp.nlargest(1)
# Out:
# Region
# NorthernAmerica    57659.0
# Name: GDP per capita (current US$), dtype: float64

# %%
himp=data.groupby('Region')['International trade: Imports (million US$)'].mean()
himp.nlargest(1)
# Out:
# Region
# NorthernAmerica    663552.25
# Name: International trade: Imports (million US$), dtype: float64

# %% [markdown]
# ## 5. Find out which region has more consistent with respect to GDP per capita (current US$)

# %%
std=data.groupby('Region')['GDP per capita (current US$)'].std()
std
# Out:
# Region
# Caribbean            14579.371326
# CentralAmerica        4180.440883
# CentralAsia           4152.215490
# EasternAfrica         3716.131770
# EasternAsia          27485.120923
# EasternEurope         5415.488739
# Melanesia            13855.842686
# Micronesia            4820.669694
# MiddleAfrica          5274.846281
# NorthernAfrica         974.706575
# NorthernAmerica      25749.619445
# NorthernEurope       20671.030185
# Oceania               9233.329638
# Polynesia             6956.250286
# South-easternAsia    16311.810656
# SouthAmerica          4273.707394
# SouthernAfrica        2177.551120
# SouthernAsia          2855.708179
# SouthernEurope        9541.703216
# WesternAfrica          815.095399
# WesternAsia          18812.151459
# WesternEurope        24770.467728
# Name: GDP per capita (current US$), dtype: float64

# %%
print('The Region that has more consistent with respect to GDP per capita (current US$) : ', std.nsmallest(1))
# Out:
# The Region that has more consistent with respect to GDP per capita (current US$) :  Region
# WesternAfrica    815.095399
# Name: GDP per capita (current US$), dtype: float64
